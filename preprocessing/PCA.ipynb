# %%
import pandas as pd

# %%
df = pd.read_csv("../fake-news/train_clean.csv")

# %%
df
# Out:
#           id                                              title  \
# 0          0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1          1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2          2                  Why the Truth Might Get You Fired
# 3          3   Civilians Killed In Single US Airstrike Have ...
# 4          4  Iranian woman jailed for fictional unpublished...
# ...      ...                                                ...
# 17969  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 17970  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 17971  20797  Macy’s Is Said to Receive Takeover Approach by...
# 17972  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 17973  20799                            What Keeps the F- Alive
#
#                                           author  \
# 0                                  Darrell Lucus
# 1                                Daniel J. Flynn
# ...
